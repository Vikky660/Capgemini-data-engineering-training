-- %%
CREATE TABLE CustomerUsage (
    customer_id INT PRIMARY KEY,
    customer_name VARCHAR(50),
    plan_type VARCHAR(20),
    data_used_gb INT,
    call_minutes INT,
    monthly_bill DECIMAL(10,2)
);

-- %%
INSERT INTO CustomerUsage VALUES
(1, 'Veena', 'Postpaid', 9, 471, 842.03),
(2, 'Veer', 'Postpaid', 7, 354, 434.94),
(3, 'Mohan', 'Prepaid', 33, 497, 569.23),
(4, 'Pratik', 'Prepaid', 15, 113, 1107.48),
(5, 'Farhan', 'Prepaid', 14, 1284, 845.75),
(6, 'Jiya', 'Postpaid', 28, 1578, 1325.15);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>6</td><td>6</td></tr></tbody></table></div>

-- %%
SELECT *,
CASE
    WHEN plan_type = 'Prepaid' AND (monthly_bill > 400 OR call_minutes > 550)
        THEN 'Suggest Postpaid Upgrade'
    WHEN plan_type = 'Prepaid'
        THEN 'No Upgrade'
    WHEN plan_type = 'Postpaid' AND data_used_gb > 25
        THEN 'Suggest Premium Plan'
    ELSE 'Satisfactory Usage'
END AS PlanUpgrade
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>PlanUpgrade</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Satisfactory Usage</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Satisfactory Usage</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Suggest Postpaid Upgrade</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Suggest Postpaid Upgrade</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Suggest Postpaid Upgrade</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Suggest Premium Plan</td></tr></tbody></table></div>

-- %%
SELECT *,
CASE
    WHEN plan_type = 'Postpaid' AND data_used_gb >= 30 THEN 'Heavy User - Postpaid'
    WHEN plan_type = 'Postpaid' AND data_used_gb BETWEEN 15 AND 29 THEN 'Moderate User - Postpaid'
    WHEN plan_type = 'Postpaid' THEN 'Light User - Postpaid'
    WHEN plan_type = 'Prepaid' AND data_used_gb >= 20 THEN 'Heavy User - Prepaid'
    ELSE 'Light User - Prepaid'
END AS UserType
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>UserType</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Light User - Postpaid</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Light User - Postpaid</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Heavy User - Prepaid</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Light User - Prepaid</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Light User - Prepaid</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Moderate User - Postpaid</td></tr></tbody></table></div>

-- %%
SELECT *,
CASE
    WHEN call_minutes > 1200 AND monthly_bill > 1000 THEN 'Excessive Talker - Premium'
    WHEN call_minutes > 1200 THEN 'Excessive Talker - Standard'
    WHEN call_minutes BETWEEN 800 AND 1200 THEN 'Frequent Caller'
    ELSE 'Normal Caller'
END AS VoicePattern
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>VoicePattern</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Normal Caller</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Normal Caller</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Normal Caller</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Normal Caller</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Excessive Talker - Standard</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Excessive Talker - Premium</td></tr></tbody></table></div>

-- %%
SELECT *,
CASE
    WHEN plan_type = 'Postpaid' AND data_used_gb > 25 AND call_minutes > 1000
        THEN 'Combo Offer'
    WHEN plan_type = 'Prepaid' AND monthly_bill > 600
        THEN 'Recharge Cashback Offer'
    ELSE 'No Offer'
END AS OfferStatus
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>OfferStatus</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>No Offer</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>No Offer</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>No Offer</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Recharge Cashback Offer</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Recharge Cashback Offer</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Combo Offer</td></tr></tbody></table></div>

-- %%
SELECT *,
CASE
    WHEN data_used_gb > 25 AND call_minutes > 1000 THEN 'Gold Tier'
    WHEN data_used_gb > 25 THEN 'Silver Tier'
    WHEN call_minutes > 800 THEN 'Bronze Tier'
    ELSE 'Basic Tier'
END AS RewardTier
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>RewardTier</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Basic Tier</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Basic Tier</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Silver Tier</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Basic Tier</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Bronze Tier</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Gold Tier</td></tr></tbody></table></div>

-- %%
SELECT *,
CASE
    WHEN plan_type = 'Postpaid' AND monthly_bill < 500 THEN 'Underutilized Postpaid'
    WHEN plan_type = 'Prepaid' AND monthly_bill > 900 THEN 'Overpaying Prepaid'
    ELSE 'Plan Matches Usage'
END AS UsageCheck
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>UsageCheck</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Plan Matches Usage</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Underutilized Postpaid</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Plan Matches Usage</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Overpaying Prepaid</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Plan Matches Usage</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Plan Matches Usage</td></tr></tbody></table></div>

-- %%
SELECT *,
CASE
    WHEN data_used_gb > 25 AND call_minutes > 1000 AND monthly_bill > 1200 THEN 'Super User'
    WHEN data_used_gb > 25 AND call_minutes > 1000 THEN 'High Usage Customer'
    ELSE 'Standard User'
END AS UsageCategory
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>UsageCategory</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Standard User</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Standard User</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Standard User</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Standard User</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Standard User</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Super User</td></tr></tbody></table></div>

-- %%
SELECT *,
CASE
    WHEN call_minutes > data_used_gb * 30 THEN 'Voice Oriented User'
    WHEN data_used_gb > call_minutes / 30 THEN 'Data Oriented User'
    ELSE 'Balanced Usage'
END AS Preference
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>Preference</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Voice Oriented User</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Voice Oriented User</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Data Oriented User</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Data Oriented User</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Voice Oriented User</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Voice Oriented User</td></tr></tbody></table></div>

-- %%
SELECT *,
CASE
    WHEN monthly_bill > 1000 AND plan_type = 'Prepaid'
        THEN 'Offer Switch + Discount'
    WHEN monthly_bill > 1000 AND plan_type = 'Postpaid'
        THEN 'Offer Loyalty Discount'
    ELSE 'No Discount'
END AS DiscountOffer
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>DiscountOffer</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>No Discount</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>No Discount</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>No Discount</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Offer Switch + Discount</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>No Discount</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Offer Loyalty Discount</td></tr></tbody></table></div>

-- %%
SELECT *,
CASE
    WHEN data_used_gb > 25 AND monthly_bill < 700 THEN 'High Efficiency User'
    WHEN data_used_gb > 25 THEN 'Premium Digital User'
    ELSE 'Standard Engagement'
END AS Engagement
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>Engagement</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Standard Engagement</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Standard Engagement</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>High Efficiency User</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Standard Engagement</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Standard Engagement</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Premium Digital User</td></tr></tbody></table></div>

-- %%
SELECT *,
CASE
    WHEN call_minutes > 1500 AND data_used_gb < 10 THEN 'Heavy Voice, Low Data'
    WHEN data_used_gb > 25 AND call_minutes < 500 THEN 'Heavy Data, Light Talk'
    ELSE 'Balanced or Low Usage'
END AS UsageType
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>UsageType</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Balanced or Low Usage</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Balanced or Low Usage</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Heavy Data, Light Talk</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Balanced or Low Usage</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Balanced or Low Usage</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Balanced or Low Usage</td></tr></tbody></table></div>

-- %%
SELECT *,
CASE
    WHEN plan_type = 'Postpaid' AND monthly_bill > 800 AND call_minutes > 1200
        THEN 'Elite Postpaid User'
    WHEN plan_type = 'Postpaid' AND monthly_bill > 800
        THEN 'Premium Postpaid User'
    ELSE 'Prepaid User'
END AS PlanCategory
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>PlanCategory</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Premium Postpaid User</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Prepaid User</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Prepaid User</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Prepaid User</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Prepaid User</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Elite Postpaid User</td></tr></tbody></table></div>

-- %%
SELECT *,
CASE
    WHEN data_used_gb > 20 AND monthly_bill BETWEEN 800 AND 1000
        THEN 'Gold Data Pack Suggested'
    WHEN data_used_gb > 30
        THEN 'Platinum Data Pack Suggested'
    ELSE 'Standard Plan'
END AS DataPack
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>DataPack</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Standard Plan</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Standard Plan</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Platinum Data Pack Suggested</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Standard Plan</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Standard Plan</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Standard Plan</td></tr></tbody></table></div>

-- %%
SELECT *,
CASE
    WHEN call_minutes > 1000 AND monthly_bill < 700 THEN 'Value Talker'
    WHEN call_minutes > 1000 THEN 'Premium Talker'
    ELSE 'Normal Caller'
END AS TalkerType
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>TalkerType</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Normal Caller</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Normal Caller</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Normal Caller</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Normal Caller</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Premium Talker</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Premium Talker</td></tr></tbody></table></div>

-- %%
SELECT *,
CASE
    WHEN plan_type = 'Prepaid' AND data_used_gb > 25 THEN 'Prepaid Power User'
    WHEN plan_type = 'Postpaid' AND data_used_gb > 25 THEN 'Postpaid Power User'
    ELSE 'Normal User'
END AS PowerUser
FROM CustomerUsage;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>plan_type</th><th>data_used_gb</th><th>call_minutes</th><th>monthly_bill</th><th>PowerUser</th></tr></thead><tbody><tr><td>1</td><td>Veena</td><td>Postpaid</td><td>9</td><td>471</td><td>842.03</td><td>Normal User</td></tr><tr><td>2</td><td>Veer</td><td>Postpaid</td><td>7</td><td>354</td><td>434.94</td><td>Normal User</td></tr><tr><td>3</td><td>Mohan</td><td>Prepaid</td><td>33</td><td>497</td><td>569.23</td><td>Prepaid Power User</td></tr><tr><td>4</td><td>Pratik</td><td>Prepaid</td><td>15</td><td>113</td><td>1107.48</td><td>Normal User</td></tr><tr><td>5</td><td>Farhan</td><td>Prepaid</td><td>14</td><td>1284</td><td>845.75</td><td>Normal User</td></tr><tr><td>6</td><td>Jiya</td><td>Postpaid</td><td>28</td><td>1578</td><td>1325.15</td><td>Postpaid Power User</td></tr></tbody></table></div>
