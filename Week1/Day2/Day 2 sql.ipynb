-- %%
CREATE OR REPLACE TABLE Employee (
emp_id INT PRIMARY KEY,
emp_name VARCHAR(50),
department VARCHAR(50),
salary DECIMAL(10, 2),
joining_date DATE
);
INSERT INTO Employee (emp_id, emp_name, department, salary, joining_date) VALUES
(1, 'Karthik', 'HR', 60000.00, '2021-01-15'),
(2, 'Pratik', 'Finance', 70000.00, '2021-03-10'),
(3, 'Veer', 'HR', 55000.00, '2021-06-20'),
(4, 'Priya', 'Finance', 80000.00, '2022-01-05'),
(5, 'Ajay', 'Engineering', 75000.00, '2020-11-01'),
(6, 'Vijay', 'Engineering', 78000.00, '2019-05-22'),
(7, 'Veena', 'HR', 62000.00, '2023-03-12'),
(8, 'Meena', 'Marketing', 65000.00, '2022-08-18');

CREATE OR REPLACE TABLE Sales (
sales_id INT PRIMARY KEY,
emp_id INT,
product VARCHAR(50),
amount DECIMAL(10, 2),
sale_date DATE
);
INSERT INTO Sales (sales_id, emp_id, product, amount, sale_date) VALUES
(1, 1, 'Laptop', 50000.00, '2023-01-15'),
(2, 2, 'Mobile', 30000.00, '2023-02-18'),
(3, 3, 'Tablet', 20000.00, '2023-02-25'),
(4, 4, 'Laptop', 45000.00, '2023-03-05'),
(5, 5, 'Mobile', 35000.00, '2023-03-12'),
(6, 6, 'Tablet', 25000.00, '2023-03-20'),
(7, 7, 'Laptop', 60000.00, '2023-04-01'),
(8, 8, 'Mobile', 40000.00, '2023-04-10');


select * from Employee;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
select * from Sales;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
select SUM(Salary) as TOTAL_SALARY , department from Employee Group By department;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TOTAL_SALARY</th><th>department</th></tr></thead><tbody><tr><td>177000.00</td><td>HR</td></tr><tr><td>150000.00</td><td>Finance</td></tr><tr><td>153000.00</td><td>Engineering</td></tr><tr><td>65000.00</td><td>Marketing</td></tr></tbody></table></div>

-- %%
select count(*) as No_Of_Employees , department from Employee Group By department;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>No_Of_Employees</th><th>department</th></tr></thead><tbody><tr><td>3</td><td>HR</td></tr><tr><td>2</td><td>Finance</td></tr><tr><td>2</td><td>Engineering</td></tr><tr><td>1</td><td>Marketing</td></tr></tbody></table></div>

-- %%
select avg(Salary) as AVG_Salary , department from Employee Group By department;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AVG_Salary</th><th>department</th></tr></thead><tbody><tr><td>59000.000000</td><td>HR</td></tr><tr><td>75000.000000</td><td>Finance</td></tr><tr><td>76500.000000</td><td>Engineering</td></tr><tr><td>65000.000000</td><td>Marketing</td></tr></tbody></table></div>

-- %%
select max(Salary) as Max_Salary , department from Employee Group By department;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Max_Salary</th><th>department</th></tr></thead><tbody><tr><td>62000.00</td><td>HR</td></tr><tr><td>80000.00</td><td>Finance</td></tr><tr><td>78000.00</td><td>Engineering</td></tr><tr><td>65000.00</td><td>Marketing</td></tr></tbody></table></div>

-- %%
select SUM(Salary) as Total_Salary , department from Employee Group By department having SUM(Salary)>100000;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Total_Salary</th><th>department</th></tr></thead><tbody><tr><td>177000.00</td><td>HR</td></tr><tr><td>150000.00</td><td>Finance</td></tr><tr><td>153000.00</td><td>Engineering</td></tr></tbody></table></div>

-- %%
select count(*) as No_Of_Employees , department from Employee Group By department having count(*)>2;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>No_Of_Employees</th><th>department</th></tr></thead><tbody><tr><td>3</td><td>HR</td></tr></tbody></table></div>

-- %%
select avg(Salary) as AVG_E_Salary, department from Employee  where joining_date> '2021-01-01' Group By department;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AVG_E_Salary</th><th>department</th></tr></thead><tbody><tr><td>59000.000000</td><td>HR</td></tr><tr><td>75000.000000</td><td>Finance</td></tr><tr><td>65000.000000</td><td>Marketing</td></tr></tbody></table></div>

-- %%
select max(Salary) as Max_Salary, department From Employee Group By department having max(Salary)>75000;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Max_Salary</th><th>department</th></tr></thead><tbody><tr><td>80000.00</td><td>Finance</td></tr><tr><td>78000.00</td><td>Engineering</td></tr></tbody></table></div>

-- %%
select SUM(Salary) as Total_Salary , department from Employee Group By department having SUM(Salary)<150000;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Total_Salary</th><th>department</th></tr></thead><tbody><tr><td>65000.00</td><td>Marketing</td></tr></tbody></table></div>

-- %%
select count(*) as No_Of_Employees , department from Employee Group By department having count(*)>1;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>No_Of_Employees</th><th>department</th></tr></thead><tbody><tr><td>3</td><td>HR</td></tr><tr><td>2</td><td>Finance</td></tr><tr><td>2</td><td>Engineering</td></tr></tbody></table></div>

-- %%
select sum(Salary) as total_salary, department from Employee group by department having total_salary>125000;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_salary</th><th>department</th></tr></thead><tbody><tr><td>177000.00</td><td>HR</td></tr><tr><td>150000.00</td><td>Finance</td></tr><tr><td>153000.00</td><td>Engineering</td></tr></tbody></table></div>

-- %%
select count(*) as No_Of_Employee_ , department from Employee Group By department having No_Of_Employee_>2;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>No_Of_Employee_</th><th>department</th></tr></thead><tbody><tr><td>3</td><td>HR</td></tr></tbody></table></div>

-- %%
select avg(Salary) as AVG_Salary , department from employee group by department having avg_salary>60000;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AVG_Salary</th><th>department</th></tr></thead><tbody><tr><td>75000.000000</td><td>Finance</td></tr><tr><td>76500.000000</td><td>Engineering</td></tr><tr><td>65000.000000</td><td>Marketing</td></tr></tbody></table></div>

-- %%
select sum(Salary) as sum_of_salary , department from employee department group by department having sum_of_salary between 100000 and 200000;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sum_of_salary</th><th>department</th></tr></thead><tbody><tr><td>177000.00</td><td>HR</td></tr><tr><td>150000.00</td><td>Finance</td></tr><tr><td>153000.00</td><td>Engineering</td></tr></tbody></table></div>
